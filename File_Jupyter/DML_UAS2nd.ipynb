# %%
import pandas as pd
import numpy as np
from pathlib import Path
from bs4 import BeautifulSoup
import fitz  # PyMuPDF
import re
from tqdm.auto import tqdm

# Impor dari Hugging Face Transformers
import torch
from torch.utils.data import DataLoader
from transformers import AutoTokenizer, AutoModelForTokenClassification, AdamW, get_scheduler, DataCollatorForTokenClassification
from datasets import Dataset, DatasetDict
from seqeval.metrics import f1_score, classification_report

# %%
# === Fase 1: Pengaturan dan Fungsi Bantuan ===

# Tentukan path ke direktori data Anda
# Ganti dengan path yang sesuai di komputer Anda
try:
    # Path untuk lingkungan lokal
    DATA_DIR = Path("D:/Jupyter_File/DML_Kelompok-B/Dataset")
    TRAIN_XML_DIR = DATA_DIR / "train/XML"
    TEST_XML_DIR = DATA_DIR / "test/XML"
    TRAIN_PDF_DIR = DATA_DIR / "train/PDF"
    TEST_PDF_DIR = DATA_DIR / "test/PDF"
    TRAIN_LABELS_CSV = DATA_DIR / "train_labels.csv"
    SAMPLE_SUBMISSION_CSV = DATA_DIR / "sample_submission.csv"
except Exception:
    # Path fallback jika di lingkungan lain (misalnya, Kaggle)
    DATA_DIR = Path("./")
    TRAIN_XML_DIR = DATA_DIR / "train/XML"
    TEST_XML_DIR = DATA_DIR / "test/XML"
    TRAIN_PDF_DIR = DATA_DIR / "train/PDF"
    TEST_PDF_DIR = DATA_DIR / "test/PDF"
    TRAIN_LABELS_CSV = DATA_DIR / "train_labels.csv"
    SAMPLE_SUBMISSION_CSV = DATA_DIR / "sample_submission.csv"

# %%
#  Definisikan label dan mappingnya
# O: Outside (bukan entitas)
# B-PRIMARY: Beginning of a primary reference
# I-PRIMARY: Inside of a primary reference
# B-SECONDARY: Beginning of a secondary reference
# I-SECONDARY: Inside of a secondary reference
id2label = {0: "O", 1: "B-PRIMARY", 2: "I-PRIMARY", 3: "B-SECONDARY", 4: "I-SECONDARY"}
label2id = {"O": 0, "B-PRIMARY": 1, "I-PRIMARY": 2, "B-SECONDARY": 3, "I-SECONDARY": 4}
LABELS = list(label2id.keys())

# Model yang direkomendasikan untuk teks ilmiah
MODEL_CHECKPOINT = "allenai/scibert_scivocab_uncased"

def clean_text(text):
    """Membersihkan teks dengan menghapus spasi berlebih."""
    text = re.sub('\s+', ' ', text).strip()
    return text

def extract_text(article_id, is_train=True):
    """
    Mengekstrak teks lengkap dari file XML atau PDF.
    Memprioritaskan XML karena lebih terstruktur.
    """
    text = ""
    if is_train:
        xml_path = TRAIN_XML_DIR / f"{article_id}.xml"
        pdf_path = TRAIN_PDF_DIR / f"{article_id}.pdf"
    else:
        xml_path = TEST_XML_DIR / f"{article_id}.xml"
        pdf_path = TEST_PDF_DIR / f"{article_id}.pdf"

    # Prioritas 1: Ekstrak dari XML
    if xml_path.exists():
        try:
            with open(xml_path, 'r', encoding='utf-8') as f:
                # Menggunakan parser 'lxml' secara eksplisit
                soup = BeautifulSoup(f, 'lxml')
            
            # Cari tag body, jika tidak ada, ambil semua teks
            body = soup.find('body')
            if body:
                text = body.get_text(separator=' ', strip=True)
            else:
                text = soup.get_text(separator=' ', strip=True)
            
            if len(text) > 50: # Cek apakah ekstraksi berhasil
                return clean_text(text)
        except Exception as e:
            print(f"Error reading XML {article_id}: {e}")
            text = "" # Reset teks jika gagal

    # Prioritas 2: Ekstrak dari PDF jika XML gagal atau tidak ada
    if pdf_path.exists():
        try:
            with fitz.open(pdf_path) as doc:
                text = "".join(page.get_text() for page in doc)
            return clean_text(text)
        except Exception as e:
            print(f"Error reading PDF {article_id}: {e}")
            return "" # Kembalikan string kosong jika gagal
            
    return ""

# %%
# === Fase 2: Prapemrosesan Data untuk NER ===

def find_sublist(main_list, sub_list):
    """Menemukan indeks awal dari sublist di dalam list utama."""
    for i in range(len(main_list) - len(sub_list) + 1):
        if main_list[i:i+len(sub_list)] == sub_list:
            return i
    return -1

def create_ner_dataset(labels_df):
    """
    Mengubah dataframe label menjadi format yang siap untuk pelatihan NER.
    Ini adalah langkah paling penting.
    """
    processed_data = []
    total_labels_in_csv = 0
    found_labels_in_text = 0
    
    # Kelompokkan berdasarkan artikel untuk memproses semua label per artikel
    for article_id, group in tqdm(labels_df.groupby('article_id')):
        full_text = extract_text(article_id, is_train=True)
        if not full_text:
            continue

        text_tokens = full_text.split()
        labels = ['O'] * len(text_tokens)
        
        for _, row in group.iterrows():
            dataset_id = str(row['dataset_id'])
            label_type = str(row['type'])

            if label_type.lower() not in ['primary', 'secondary']:
                continue
            
            total_labels_in_csv += 1
            
            # --- PERBAIKAN: Pencocokan berbasis token ---
            label_tokens = dataset_id.split()
            
            start_idx = find_sublist(text_tokens, label_tokens)
            
            if start_idx != -1:
                found_labels_in_text += 1
                end_idx = start_idx + len(label_tokens)
                
                # Terapkan label IOB
                labels[start_idx] = "B-" + label_type.upper()
                for i in range(start_idx + 1, end_idx):
                    labels[i] = "I-" + label_type.upper()

        processed_data.append({
            "id": article_id,
            "tokens": text_tokens,
            "ner_tags": [label2id[l] for l in labels]
        })
    
    print(f"\nRingkasan Pencocokan Label: Berhasil menemukan {found_labels_in_text} dari {total_labels_in_csv} label di dalam teks artikel.")
    return pd.DataFrame(processed_data)

# %%
# === Fase 3: Pelatihan Model ===

def tokenize_and_align_labels(examples, tokenizer):
    """
    Menyelaraskan label IOB dengan sub-token yang dihasilkan oleh tokenizer.
    """
    tokenized_inputs = tokenizer(examples["tokens"], truncation=True, is_split_into_words=True, max_length=512)
    labels = []
    for i, label in enumerate(examples["ner_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif word_idx != previous_word_idx:
                label_ids.append(label[word_idx])
            else:
                label_ids.append(-100)
            previous_word_idx = word_idx
        labels.append(label_ids)
    tokenized_inputs["labels"] = labels
    return tokenized_inputs

def train_model(train_dataset, val_dataset):
    """
    Fungsi untuk melatih model NER.
    """
    tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)
    
    train_tokenized = train_dataset.map(lambda x: tokenize_and_align_labels(x, tokenizer), batched=True)
    val_tokenized = val_dataset.map(lambda x: tokenize_and_align_labels(x, tokenizer), batched=True)

    data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

    train_dataloader = DataLoader(
        train_tokenized.remove_columns(['tokens', 'ner_tags', 'id']), 
        batch_size=8, 
        shuffle=True,
        collate_fn=data_collator
    )
    val_dataloader = DataLoader(
        val_tokenized.remove_columns(['tokens', 'ner_tags', 'id']), 
        batch_size=8,
        collate_fn=data_collator
    )

    model = AutoModelForTokenClassification.from_pretrained(
        MODEL_CHECKPOINT,
        id2label=id2label,
        label2id=label2id
    )
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    optimizer = AdamW(model.parameters(), lr=3e-5) # Sedikit menaikkan learning rate
    num_epochs = 3 # Menaikkan jumlah epoch
    num_training_steps = num_epochs * len(train_dataloader)
    lr_scheduler = get_scheduler(
        "linear",
        optimizer=optimizer,
        num_warmup_steps=0,
        num_training_steps=num_training_steps,
    )

    for epoch in range(num_epochs):
        model.train()
        for batch in tqdm(train_dataloader, desc=f"Training Epoch {epoch+1}"):
            batch = {k: v.to(device) for k, v in batch.items()}
            outputs = model(**batch)
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            optimizer.zero_grad()

        model.eval()
        all_predictions = []
        all_true_labels = []
        for batch in tqdm(val_dataloader, desc=f"Validation Epoch {epoch+1}"):
            batch = {k: v.to(device) for k, v in batch.items()}
            with torch.no_grad():
                outputs = model(**batch)
            
            predictions = outputs.logits.argmax(dim=-1)
            true_labels = batch["labels"]
            
            for pred, true in zip(predictions, true_labels):
                pred_labels = [id2label[p.item()] for p, l in zip(pred, true) if l != -100]
                true_labels_list = [id2label[l.item()] for l in true if l != -100]
                all_predictions.append(pred_labels)
                all_true_labels.append(true_labels_list)
        
        has_entities = any(label != 'O' for seq in all_true_labels for label in seq)

        if has_entities:
            f1 = f1_score(all_true_labels, all_predictions)
            print(f"Epoch {epoch+1}, Validation F1-Score: {f1:.4f}")
            print(classification_report(all_true_labels, all_predictions, zero_division=0))
        else:
            print(f"Epoch {epoch+1}: Tidak ada entitas berlabel yang ditemukan di set validasi. Melewatkan laporan klasifikasi.")
            f1 = 0.0 
            print(f"Epoch {epoch+1}, Validation F1-Score: {f1:.4f}")

    model.save_pretrained("./mdc_ner_model")
    tokenizer.save_pretrained("./mdc_ner_model")
    print("Model berhasil disimpan di folder './mdc_ner_model'")
    return model, tokenizer

# %%
# === Fase 4: Prediksi dan Pembuatan Submission ===

def predict_on_test_data(model, tokenizer):
    """
    Membuat prediksi pada data uji dan menghasilkan file submission.
    """
    test_ids = [p.stem for p in TEST_XML_DIR.glob("*.xml")]
    if not test_ids:
        test_ids = [p.stem for p in TEST_PDF_DIR.glob("*.pdf")]

    all_rows = []

    for article_id in tqdm(test_ids, desc="Predicting on test set"):
        text = extract_text(article_id, is_train=False)
        if not text:
            continue

        inputs = tokenizer(text, return_tensors="pt", max_length=512, truncation=True, return_offsets_mapping=True)
        offset_mapping = inputs.pop("offset_mapping").squeeze().tolist()
        
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        inputs = {k: v.to(device) for k, v in inputs.items()}
        
        with torch.no_grad():
            logits = model(**inputs).logits
        
        predicted_token_class_ids = logits.argmax(-1).squeeze().tolist()
        
        current_entity_tokens = []
        current_label = "O"
        last_end_offset = 0

        for token_id, offset in zip(predicted_token_class_ids, offset_mapping):
            label = id2label[token_id]
            start, end = offset
            
            if start == end: continue

            if label.startswith("B-"):
                if current_entity_tokens:
                    entity_type = current_label.split('-')[1].capitalize()
                    all_rows.append({
                        "article_id": article_id,
                        "dataset_id": text[current_entity_tokens[0][1]:last_end_offset],
                        "type": entity_type
                    })
                current_entity_tokens = [(token_id, start, end)]
                current_label = label
                last_end_offset = end
            elif label.startswith("I-") and current_label != "O" and label.split('-')[1] == current_label.split('-')[1]:
                current_entity_tokens.append((token_id, start, end))
                last_end_offset = end
            else:
                if current_entity_tokens:
                    entity_type = current_label.split('-')[1].capitalize()
                    all_rows.append({
                        "article_id": article_id,
                        "dataset_id": text[current_entity_tokens[0][1]:last_end_offset],
                        "type": entity_type
                    })
                current_entity_tokens = []
                current_label = "O"

        if current_entity_tokens:
            entity_type = current_label.split('-')[1].capitalize()
            all_rows.append({
                "article_id": article_id,
                "dataset_id": text[current_entity_tokens[0][1]:last_end_offset],
                "type": entity_type
            })

    if not all_rows:
        submission_df = pd.DataFrame(columns=['row_id', 'article_id', 'dataset_id', 'type'])
    else:
        submission_df = pd.DataFrame(all_rows)
        submission_df.insert(0, 'row_id', range(len(submission_df)))

    submission_df = submission_df[['row_id', 'article_id', 'dataset_id', 'type']]
    submission_df.to_csv("submission.csv", index=False)
    print("File submission.csv berhasil dibuat.")

# %%
# === Main Execution ===
if __name__ == '__main__':
    # 1. Muat label training
    print("Memuat label training...")
    train_labels_df = pd.read_csv(TRAIN_LABELS_CSV)
    
    # Filter hanya baris yang memiliki label, bukan 'Missing'
    labeled_df = train_labels_df[train_labels_df['type'] != 'Missing'].copy()

    # 2. Buat dataset NER
    print("Membuat dataset NER dari file teks...")
    ner_data = create_ner_dataset(labeled_df)
    
    if ner_data.empty:
        print("Tidak ada data yang bisa diproses. Pastikan path ke dataset sudah benar.")
    else:
        # 3. Bagi data menjadi train dan validation
        print("Membagi data menjadi set training dan validasi...")
        dataset = Dataset.from_pandas(ner_data)
        train_val_split = dataset.train_test_split(test_size=0.2, seed=42)
        
        # Buat DatasetDict
        mdc_dataset = DatasetDict({
            'train': train_val_split['train'],
            'validation': train_val_split['test']
        })
        print("Struktur dataset:")
        print(mdc_dataset)

        # 4. Latih model
        print("\nMemulai pelatihan model...")
        # Catatan: Langkah ini bisa memakan waktu lama dan membutuhkan GPU untuk performa terbaik.
        trained_model, tokenizer = train_model(mdc_dataset['train'], mdc_dataset['validation'])

        # 5. Buat prediksi
        print("\nMembuat prediksi pada data uji...")
        predict_on_test_data(trained_model, tokenizer)
# Out:
# Memuat label training...
# Membuat dataset NER dari file teks...
#   0%|          | 0/214 [00:00<?, ?it/s]
# Error reading XML 10.1002_2017jc013030: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.4466: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.5260: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.6144: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.6303: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.9627: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ecs2.4619: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_esp.5090: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_mp.14424: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1007_s00259-022-06053-8: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1007_s00382-022-06361-7: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1007_s00442-022-05201-z: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1007_s12559-020-09751-3: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1016_j.ast.2022.107401: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1016_j.cpc.2024.109087: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1016_j.dib.2022.108797: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1016_j.dib.2023.109949: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1016_j.ecolind.2021.107934: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1016_j.jobe.2023.107105: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1016_j.molcel.2018.11.006: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1016_j.scitotenv.2024.171850: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1017_s0007123423000601: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1021_acscentsci.1c01109: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1021_acsomega.3c06074: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1021_jacs.2c06519: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1029_2018gl078007: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1029_2020jf005675: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1029_2021gl096173: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1029_2022gl100473: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1029_2023ea002840: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1029_2023wr035126: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_hdy.2015.99: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41396-020-00885-8: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41437-020-0318-8: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41467-018-04041-x: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41467-018-07681-1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41558-022-01301-z: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41562-021-01247-w: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41597-019-0101-y: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41597-022-01555-4: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41597-023-02280-2: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41598-020-59839-x: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41598-021-85671-y: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_s41598-024-56373-y: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1038_sdata.2017.167: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1039_d1ee03696c: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1039_d2cc00847e: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1073_pnas.2306723120: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1080_21645515.2023.2189598: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1093_beheco_arad016: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1093_beheco_arw167: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1093_beheco_arz101: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1093_bib_bbab395: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1093_evolut_qpad206: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1093_nar_gkp1049: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1093_sysbio_syy011: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1098_rsbl.2015.0113: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1098_rsos.160417: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1098_rsos.170796: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1098_rsos.190841: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1098_rsos.210982: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1098_rspb.2015.0371: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1098_rspb.2015.1498: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1098_rspb.2015.2726: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1101_2022.02.10.480011: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1101_2022.07.21.501061: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1103_physrevresearch.4.023008: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1107_s2059798322005691: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1109_access.2024.3385658: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_1365-2435.13431: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_1365-2435.13569: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_1365-2656.12382: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_1365-2656.12491: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_1365-2664.13136: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_2041-210x.12453: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_2041-210x.13817: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_acel.13089: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_cas.12935: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_ejn.13855: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_eva.12151: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_eva.12446: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_eva.12768: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_gcb.13914: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_ggr.12517: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_mec.16977: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1111_njb.02077: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1128_JVI.01717-21: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1128_spectrum.00422-24: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1130_ges01387.1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1136_jitc-2021-003114: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1145_3461702.3462538: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1177_0018720820970751: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1186_s13039-022-00631-z: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1186_s13071-018-2842-4: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1212_wnl.0000000000006035: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1242_bio.035071: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1242_dev.138545: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.12688_f1000research.10556.1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.12688_f1000research.11698.1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.12688_f1000research.13064.1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.12688_f1000research.13483.1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.12688_f1000research.13622.1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.12688_f1000research.13852.1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.12688_f1000research.4660.1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# MuPDF error: unsupported error: cannot create appearance stream for  annotations
#
# Error reading XML 10.1371_journal.pcbi.1011828: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pntd.0005385: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0070749: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0117675: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0137181: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0139215: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0146274: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0159387: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0188323: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0198382: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0200041: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0212669: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0220399: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0253228: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0262974: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1371_journal.pone.0284951: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1534_g3.119.400401: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1534_g3.119.400993: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1617_s11527-023-02260-3: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.17581_bp.2020.09104: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.20944_preprints202009.0353.v1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.21105_joss.04237: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.21203_rs.3.rs-3338732_v1: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3133_cir1497: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3133_fs20233046: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3133_ofr20201035: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3133_ofr20231026: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3133_ofr20231027: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3389_fcell.2020.618552: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3389_fcimb.2024.1292467: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3389_feart.2023.1205211: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3389_fmicb.2024.1456637: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3389_fpls.2023.1160645: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3390_d13010019: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3390_microorganisms8121872: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3390_rs4102923: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3390_s19030479: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3390_s23094491: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3390_s23177333: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3390_v11060565: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3897_neobiota.82.87455: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.3897_zookeys.500.9360: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_acp-2021-570: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_acp-22-2769-2022: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_acp-22-5701-2022: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_amt-15-3969-2022: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_essd-12-1287-2020: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_essd-2019-206: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_essd-2023-187: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_essd-2023-198: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_gmd-12-4221-2019: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5194_gmd-13-335-2020: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.5937_bnhmb1811227u: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7554_eLife.63194: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7554_eLife.72626: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7554_elife.29944: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7554_elife.42722: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7554_elife.62329: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7554_elife.63455: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7554_elife.73695: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7554_elife.74937: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7717_peerj.10452: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7717_peerj.11352: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7717_peerj.12422: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.7717_peerj.13193: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
#
# Ringkasan Pencocokan Label: Berhasil menemukan 319 dari 719 label di dalam teks artikel.
# Membagi data menjadi set training dan validasi...
# Struktur dataset:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 171
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'ner_tags'],
#         num_rows: 43
#     })
# })
#
# Memulai pelatihan model...
# d:\Jupyter_File\DML_Kelompok-B\.venv\Lib\site-packages\huggingface_hub\file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map:   0%|          | 0/171 [00:00<?, ? examples/s]
# Map:   0%|          | 0/43 [00:00<?, ? examples/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at allenai/scibert_scivocab_uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# d:\Jupyter_File\DML_Kelompok-B\.venv\Lib\site-packages\transformers\optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Training Epoch 1:   0%|          | 0/22 [00:00<?, ?it/s]
# Validation Epoch 1:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 1: Tidak ada entitas berlabel yang ditemukan di set validasi. Melewatkan laporan klasifikasi.
# Epoch 1, Validation F1-Score: 0.0000
# Training Epoch 2:   0%|          | 0/22 [00:00<?, ?it/s]
# Validation Epoch 2:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 2: Tidak ada entitas berlabel yang ditemukan di set validasi. Melewatkan laporan klasifikasi.
# Epoch 2, Validation F1-Score: 0.0000
# Training Epoch 3:   0%|          | 0/22 [00:00<?, ?it/s]
# Validation Epoch 3:   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch 3: Tidak ada entitas berlabel yang ditemukan di set validasi. Melewatkan laporan klasifikasi.
# Epoch 3, Validation F1-Score: 0.0000
# Model berhasil disimpan di folder './mdc_ner_model'
#
# Membuat prediksi pada data uji...
# Predicting on test set:   0%|          | 0/25 [00:00<?, ?it/s]
# Error reading XML 10.1002_2017jc013030: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_anie.201916483: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_anie.202005531: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_anie.202007717: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_chem.201902131: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_chem.201903120: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_chem.202000235: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_chem.202001412: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_chem.202001668: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_chem.202003167: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_cssc.202201821: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.3985: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.4466: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.5260: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.5395: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.6144: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.6303: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.6784: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.961: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ece3.9627: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ecs2.4619: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ejic.201900904: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_ejoc.202000916: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_esp.5090: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Error reading XML 10.1002_mp.14424: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# File submission.csv berhasil dibuat.
